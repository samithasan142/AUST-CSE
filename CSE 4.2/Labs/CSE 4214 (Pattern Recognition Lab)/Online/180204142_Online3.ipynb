# %% [markdown]
# # Importing Library

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
main_directory1  = '/content/iris.csv'
train = pd.read_csv(main_directory1)

# %%
print(train)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Dividing Into Classes

# %%
train = train.sample(frac = 1)
print(train)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 71            6.1          2.8           4.0          1.3  Versicolor
# 76            6.8          2.8           4.8          1.4  Versicolor
# 128           6.4          2.8           5.6          2.1   Virginica
# 50            7.0          3.2           4.7          1.4  Versicolor
# 56            6.3          3.3           4.7          1.6  Versicolor
# ..            ...          ...           ...          ...         ...
# 130           7.4          2.8           6.1          1.9   Virginica
# 28            5.2          3.4           1.4          0.2      Setosa
# 139           6.9          3.1           5.4          2.1   Virginica
# 35            5.0          3.2           1.2          0.2      Setosa
# 37            4.9          3.6           1.4          0.1      Setosa
#
# [150 rows x 5 columns]

# %%
test = train.iloc[101:150, :]
train = train.iloc[0:100, :]

# %%
class_1 = train[train['variety']=='Virginica']
class_1 = class_1.loc[:, ["sepal.length", "petal.length", 'variety']]
class_1
# Out:
#      sepal.length  petal.length    variety
# 128           6.4           5.6  Virginica
# 144           6.7           5.7  Virginica
# 124           6.7           5.7  Virginica
# 135           7.7           6.1  Virginica
# 113           5.7           5.0  Virginica
# 118           7.7           6.9  Virginica
# 114           5.8           5.1  Virginica
# 110           6.5           5.1  Virginica
# 147           6.5           5.2  Virginica
# 134           6.1           5.6  Virginica
# 117           7.7           6.7  Virginica
# 122           7.7           6.7  Virginica
# 142           5.8           5.1  Virginica
# 141           6.9           5.1  Virginica
# 123           6.3           4.9  Virginica
# 126           6.2           4.8  Virginica
# 148           6.2           5.4  Virginica
# 108           6.7           5.8  Virginica
# 109           7.2           6.1  Virginica
# 104           6.5           5.8  Virginica
# 138           6.0           4.8  Virginica
# 111           6.4           5.3  Virginica
# 149           5.9           5.1  Virginica
# 115           6.4           5.3  Virginica
# 107           7.3           6.3  Virginica
# 136           6.3           5.6  Virginica
# 140           6.7           5.6  Virginica
# 106           4.9           4.5  Virginica
# 121           5.6           4.9  Virginica

# %%
class_2 = train[train['variety']=='Setosa']
class_2 = class_2.loc[:, ["sepal.length", "petal.length", 'variety']]
class_2
# Out:
#     sepal.length  petal.length variety
# 15           5.7           1.5  Setosa
# 23           5.1           1.7  Setosa
# 49           5.0           1.4  Setosa
# 16           5.4           1.3  Setosa
# 45           4.8           1.4  Setosa
# 34           4.9           1.5  Setosa
# 41           4.5           1.3  Setosa
# 25           5.0           1.6  Setosa
# 27           5.2           1.5  Setosa
# 22           4.6           1.0  Setosa
# 13           4.3           1.1  Setosa
# 3            4.6           1.5  Setosa
# 8            4.4           1.4  Setosa
# 19           5.1           1.5  Setosa
# 32           5.2           1.5  Setosa
# 0            5.1           1.4  Setosa
# 42           4.4           1.3  Setosa
# 47           4.6           1.4  Setosa
# 12           4.8           1.4  Setosa
# 31           5.4           1.5  Setosa
# 17           5.1           1.4  Setosa
# 20           5.4           1.7  Setosa
# 21           5.1           1.5  Setosa
# 6            4.6           1.4  Setosa
# 9            4.9           1.5  Setosa
# 40           5.0           1.3  Setosa
# 38           4.4           1.3  Setosa
# 2            4.7           1.3  Setosa
# 5            5.4           1.7  Setosa
# 36           5.5           1.3  Setosa
# 43           5.0           1.6  Setosa
# 1            4.9           1.4  Setosa
# 44           5.1           1.9  Setosa
# 48           5.3           1.5  Setosa
# 10           5.4           1.5  Setosa
# 7            5.0           1.5  Setosa

# %%
class_3 = train[train['variety']=='Versicolor']
class_3 = class_3.loc[:, ["sepal.length", "petal.length", 'variety']]
class_3
# Out:
#     sepal.length  petal.length     variety
# 71           6.1           4.0  Versicolor
# 76           6.8           4.8  Versicolor
# 50           7.0           4.7  Versicolor
# 56           6.3           4.7  Versicolor
# 73           6.1           4.7  Versicolor
# 85           6.0           4.5  Versicolor
# 80           5.5           3.8  Versicolor
# 82           5.8           3.9  Versicolor
# 66           5.6           4.5  Versicolor
# 68           6.2           4.5  Versicolor
# 78           6.0           4.5  Versicolor
# 96           5.7           4.2  Versicolor
# 67           5.8           4.1  Versicolor
# 70           5.9           4.8  Versicolor
# 90           5.5           4.4  Versicolor
# 98           5.1           3.0  Versicolor
# 51           6.4           4.5  Versicolor
# 58           6.6           4.6  Versicolor
# 89           5.5           4.0  Versicolor
# 62           6.0           4.0  Versicolor
# 95           5.7           4.2  Versicolor
# 77           6.7           5.0  Versicolor
# 93           5.0           3.3  Versicolor
# 84           5.4           4.5  Versicolor
# 59           5.2           3.9  Versicolor
# 97           6.2           4.3  Versicolor
# 53           5.5           4.0  Versicolor
# 55           5.7           4.5  Versicolor
# 72           6.3           4.9  Versicolor
# 75           6.6           4.4  Versicolor
# 65           6.7           4.4  Versicolor
# 57           4.9           3.3  Versicolor
# 92           5.8           4.0  Versicolor
# 64           5.6           3.6  Versicolor
# 94           5.6           4.2  Versicolor

# %% [markdown]
# # Plotting Graph

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1.5,1.5])
ax.scatter(class_1['sepal.length'], class_1['petal.length'], color='dodgerblue', label="Class 1")
ax.scatter(class_2['sepal.length'], class_2['petal.length'] , color='y', label="Class 2")
ax.scatter(class_3['sepal.length'], class_3['petal.length'] , color='g', label="Class 3")
ax.set_xlabel('first Column')
ax.set_ylabel('Second Column')
ax.set_title('scatter plot')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Defining BubbleSort Function

# %%
type(train)
train
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 71            6.1          2.8           4.0          1.3  Versicolor
# 76            6.8          2.8           4.8          1.4  Versicolor
# 128           6.4          2.8           5.6          2.1   Virginica
# 50            7.0          3.2           4.7          1.4  Versicolor
# 56            6.3          3.3           4.7          1.6  Versicolor
# ..            ...          ...           ...          ...         ...
# 121           5.6          2.8           4.9          2.0   Virginica
# 92            5.8          2.6           4.0          1.2  Versicolor
# 64            5.6          2.9           3.6          1.3  Versicolor
# 94            5.6          2.7           4.2          1.3  Versicolor
# 7             5.0          3.4           1.5          0.2      Setosa
#
# [100 rows x 5 columns]

# %%
train
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 71            6.1          2.8           4.0          1.3  Versicolor
# 76            6.8          2.8           4.8          1.4  Versicolor
# 128           6.4          2.8           5.6          2.1   Virginica
# 50            7.0          3.2           4.7          1.4  Versicolor
# 56            6.3          3.3           4.7          1.6  Versicolor
# ..            ...          ...           ...          ...         ...
# 121           5.6          2.8           4.9          2.0   Virginica
# 92            5.8          2.6           4.0          1.2  Versicolor
# 64            5.6          2.9           3.6          1.3  Versicolor
# 94            5.6          2.7           4.2          1.3  Versicolor
# 7             5.0          3.4           1.5          0.2      Setosa
#
# [100 rows x 5 columns]

# %%
def bubbleSort(array, target_label):
    for i in range(len(array)):
        for j in range(0, len(array) - i - 1):
            if array[j] > array[j + 1]:
                temp = array[j]
                array[j] = array[j+1]
                array[j+1] = temp

                temp = target_label[j]
                target_label[j] = target_label[j+1]
                target_label[j+1] = temp
    return array

# %%
def calculate_dist(x,y):
    global train    
    dist = []
    target_label = list(train['variety'])
    for i,j in zip(train['sepal.length'], train['petal.length']):
        dist.append(((i-x)**2 +(j-y)**2))        
    dist = bubbleSort(dist,target_label)
    return dist,target_label

# %%
distances = []
target_labels = []
for i,j in zip(test['sepal.length'], test['petal.length']):
    a, b = calculate_dist(i,j)
    distances.append(a)
    target_labels.append(b)

# %%
distances = np.array(distances)
distances.shape
# Out:
# (49, 100)

# %%
target_labels = np.array(target_labels)
target_labels.shape
# Out:
# (49, 100)

# %%
test = np.array(test)

# %% [markdown]
# # Taking User Input

# %%
k=input ("Enter value of k :")
k=int(k)
type(k)
# Out:
# Enter value of k :3
# int

# %% [markdown]
# # KNN Algorithm

# %%
output = []
predicted_class_1 = []
predicted_class_2 = []
prediction_text = []
for i in range(len(test)):
    count_1, count_2 = 0, 0
    print('Test Point: ', test[i])
    s = 'Test Point: '+ str(test[i]) + '\n'
    prediction_text.append(s)
    for j in range(k):
        print('Distance : ', distances[i][j], 'Class : ', target_labels[i][j])
        s = 'Distance : '+ str(distances[i][j])  + '   Class : ' + str(target_labels[i][j]) + '\n'
        prediction_text.append(s)
        if target_labels[i][j] == 1:
            count_1 += 1
        else:
            count_2 += 1    
    if count_1 > count_2:
        print('Predicted Class 1')
        prediction_text.append('Predicted Class 1' + '\n\n')
        predicted_class_1.append(list(test[i]))
    else:
        print('Predicted Class 2')
        prediction_text.append('Predicted Class 2' + '\n\n')
        predicted_class_2.append(list(test[i]))
    print('\n\n')
# Out:
# Test Point:  [6.3 3.3 6.0 2.5 'Virginica']
# Distance :  0.08000000000000014 Class :  Virginica
# Distance :  0.16000000000000028 Class :  Virginica
# Distance :  0.17000000000000037 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [5.9 3.0 4.2 1.5 'Versicolor']
# Distance :  0.020000000000000212 Class :  Versicolor
# Distance :  0.04000000000000007 Class :  Versicolor
# Distance :  0.04000000000000007 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [5.7 2.6 3.5 1.0 'Versicolor']
# Distance :  0.020000000000000122 Class :  Versicolor
# Distance :  0.12999999999999998 Class :  Versicolor
# Distance :  0.16999999999999985 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [6.8 3.2 5.9 2.3 'Virginica']
# Distance :  0.020000000000000035 Class :  Virginica
# Distance :  0.05 Class :  Virginica
# Distance :  0.05 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [4.7 3.2 1.6 0.2 'Setosa']
# Distance :  0.020000000000000122 Class :  Setosa
# Distance :  0.05 Class :  Setosa
# Distance :  0.05 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [7.1 3.0 5.9 2.1 'Virginica']
# Distance :  0.04999999999999982 Class :  Virginica
# Distance :  0.1699999999999997 Class :  Virginica
# Distance :  0.19999999999999965 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.1 3.0 4.6 1.4 'Versicolor']
# Distance :  0.010000000000000106 Class :  Versicolor
# Distance :  0.019999999999999858 Class :  Versicolor
# Distance :  0.019999999999999858 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [5.5 4.2 1.4 0.2 'Setosa']
# Distance :  0.009999999999999974 Class :  Setosa
# Distance :  0.019999999999999903 Class :  Setosa
# Distance :  0.01999999999999995 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [5.0 3.6 1.4 0.2 'Setosa']
# Distance :  0.0 Class :  Setosa
# Distance :  0.009999999999999929 Class :  Setosa
# Distance :  0.009999999999999929 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [4.8 3.1 1.6 0.2 'Setosa']
# Distance :  0.020000000000000122 Class :  Setosa
# Distance :  0.020000000000000122 Class :  Setosa
# Distance :  0.04000000000000007 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [5.8 2.7 5.1 1.9 'Virginica']
# Distance :  0.0 Class :  Virginica
# Distance :  0.0 Class :  Virginica
# Distance :  0.010000000000000106 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.3 2.5 5.0 1.9 'Virginica']
# Distance :  0.009999999999999929 Class :  Virginica
# Distance :  0.009999999999999929 Class :  Versicolor
# Distance :  0.05 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [4.8 3.4 1.6 0.2 'Setosa']
# Distance :  0.020000000000000122 Class :  Setosa
# Distance :  0.020000000000000122 Class :  Setosa
# Distance :  0.04000000000000007 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [5.6 3.0 4.1 1.3 'Versicolor']
# Distance :  0.010000000000000106 Class :  Versicolor
# Distance :  0.019999999999999858 Class :  Versicolor
# Distance :  0.019999999999999858 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [7.2 3.0 5.8 1.6 'Virginica']
# Distance :  0.0899999999999999 Class :  Virginica
# Distance :  0.25 Class :  Virginica
# Distance :  0.25999999999999995 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.0 2.2 5.0 1.5 'Virginica']
# Distance :  0.019999999999999858 Class :  Virginica
# Distance :  0.04000000000000007 Class :  Virginica
# Distance :  0.05 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [7.9 3.8 6.4 2.0 'Virginica']
# Distance :  0.12999999999999998 Class :  Virginica
# Distance :  0.12999999999999998 Class :  Virginica
# Distance :  0.1300000000000005 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [5.1 3.8 1.6 0.2 'Setosa']
# Distance :  0.009999999999999929 Class :  Setosa
# Distance :  0.009999999999999929 Class :  Setosa
# Distance :  0.009999999999999974 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [6.8 3.0 5.5 2.1 'Virginica']
# Distance :  0.019999999999999858 Class :  Virginica
# Distance :  0.05 Class :  Virginica
# Distance :  0.05 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.4 2.9 4.3 1.3 'Versicolor']
# Distance :  0.04000000000000007 Class :  Versicolor
# Distance :  0.04000000000000007 Class :  Versicolor
# Distance :  0.04999999999999982 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [5.0 3.4 1.6 0.4 'Setosa']
# Distance :  0.0 Class :  Setosa
# Distance :  0.0 Class :  Setosa
# Distance :  0.010000000000000018 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [6.0 2.7 5.1 1.6 'Versicolor']
# Distance :  0.009999999999999929 Class :  Virginica
# Distance :  0.04000000000000007 Class :  Virginica
# Distance :  0.04000000000000007 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.3 2.8 5.1 1.5 'Virginica']
# Distance :  0.039999999999999716 Class :  Virginica
# Distance :  0.039999999999999716 Class :  Versicolor
# Distance :  0.04000000000000007 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.3 2.9 5.6 1.8 'Virginica']
# Distance :  0.0 Class :  Virginica
# Distance :  0.010000000000000106 Class :  Virginica
# Distance :  0.04000000000000007 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.9 3.2 5.7 2.3 'Virginica']
# Distance :  0.04000000000000007 Class :  Virginica
# Distance :  0.04000000000000007 Class :  Virginica
# Distance :  0.05 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.9 3.1 4.9 1.5 'Versicolor']
# Distance :  0.020000000000000212 Class :  Versicolor
# Distance :  0.039999999999999716 Class :  Virginica
# Distance :  0.05 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [5.1 3.4 1.5 0.2 'Setosa']
# Distance :  0.0 Class :  Setosa
# Distance :  0.0 Class :  Setosa
# Distance :  0.009999999999999929 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [7.2 3.2 6.0 1.8 'Virginica']
# Distance :  0.009999999999999929 Class :  Virginica
# Distance :  0.09999999999999983 Class :  Virginica
# Distance :  0.25999999999999995 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [4.8 3.4 1.9 0.2 'Setosa']
# Distance :  0.0899999999999999 Class :  Setosa
# Distance :  0.1299999999999999 Class :  Setosa
# Distance :  0.12999999999999998 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [6.5 2.8 4.6 1.5 'Versicolor']
# Distance :  0.009999999999999929 Class :  Versicolor
# Distance :  0.019999999999999858 Class :  Versicolor
# Distance :  0.04999999999999964 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [7.6 3.0 6.6 2.1 'Virginica']
# Distance :  0.020000000000000212 Class :  Virginica
# Distance :  0.020000000000000212 Class :  Virginica
# Distance :  0.10000000000000053 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [5.0 2.0 3.5 1.0 'Versicolor']
# Distance :  0.04000000000000007 Class :  Versicolor
# Distance :  0.05 Class :  Versicolor
# Distance :  0.19999999999999998 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [6.7 3.0 5.2 2.3 'Virginica']
# Distance :  0.04000000000000007 Class :  Virginica
# Distance :  0.04000000000000007 Class :  Versicolor
# Distance :  0.050000000000000176 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.7 3.1 4.7 1.5 'Versicolor']
# Distance :  0.019999999999999858 Class :  Versicolor
# Distance :  0.020000000000000212 Class :  Versicolor
# Distance :  0.0899999999999999 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [6.4 3.1 5.5 1.8 'Virginica']
# Distance :  0.009999999999999929 Class :  Virginica
# Distance :  0.020000000000000035 Class :  Virginica
# Distance :  0.04000000000000007 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.5 3.0 5.5 1.8 'Virginica']
# Distance :  0.019999999999999858 Class :  Virginica
# Distance :  0.05 Class :  Virginica
# Distance :  0.05 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [6.3 2.3 4.4 1.3 'Versicolor']
# Distance :  0.019999999999999858 Class :  Versicolor
# Distance :  0.020000000000000035 Class :  Versicolor
# Distance :  0.020000000000000035 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [5.7 3.8 1.7 0.3 'Setosa']
# Distance :  0.03999999999999998 Class :  Setosa
# Distance :  0.0899999999999999 Class :  Setosa
# Distance :  0.0899999999999999 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [6.1 3.0 4.9 1.8 'Virginica']
# Distance :  0.020000000000000035 Class :  Virginica
# Distance :  0.020000000000000212 Class :  Virginica
# Distance :  0.04000000000000007 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [5.5 2.4 3.7 1.0 'Versicolor']
# Distance :  0.009999999999999929 Class :  Versicolor
# Distance :  0.01999999999999995 Class :  Versicolor
# Distance :  0.0899999999999999 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [5.6 2.5 3.9 1.1 'Versicolor']
# Distance :  0.01999999999999995 Class :  Versicolor
# Distance :  0.01999999999999995 Class :  Versicolor
# Distance :  0.01999999999999995 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [5.8 4.0 1.2 0.2 'Setosa']
# Distance :  0.09999999999999992 Class :  Setosa
# Distance :  0.09999999999999995 Class :  Setosa
# Distance :  0.1699999999999996 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [5.7 2.8 4.1 1.3 'Versicolor']
# Distance :  0.009999999999999929 Class :  Versicolor
# Distance :  0.010000000000000106 Class :  Versicolor
# Distance :  0.010000000000000106 Class :  Versicolor
# Predicted Class 2
#
#
#
# Test Point:  [6.1 2.9 4.7 1.4 'Versicolor']
# Distance :  0.0 Class :  Versicolor
# Distance :  0.019999999999999858 Class :  Virginica
# Distance :  0.020000000000000035 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [7.4 2.8 6.1 1.9 'Virginica']
# Distance :  0.04000000000000007 Class :  Virginica
# Distance :  0.050000000000000176 Class :  Virginica
# Distance :  0.0899999999999999 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [5.2 3.4 1.4 0.2 'Setosa']
# Distance :  0.010000000000000018 Class :  Setosa
# Distance :  0.010000000000000018 Class :  Setosa
# Distance :  0.010000000000000106 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [6.9 3.1 5.4 2.1 'Virginica']
# Distance :  0.0799999999999998 Class :  Virginica
# Distance :  0.09000000000000043 Class :  Virginica
# Distance :  0.12999999999999998 Class :  Virginica
# Predicted Class 2
#
#
#
# Test Point:  [5.0 3.2 1.2 0.2 'Setosa']
# Distance :  0.010000000000000018 Class :  Setosa
# Distance :  0.03999999999999998 Class :  Setosa
# Distance :  0.049999999999999906 Class :  Setosa
# Predicted Class 2
#
#
#
# Test Point:  [4.9 3.6 1.4 0.1 'Setosa']
# Distance :  0.0 Class :  Setosa
# Distance :  0.009999999999999929 Class :  Setosa
# Distance :  0.010000000000000018 Class :  Setosa
# Predicted Class 2

# %%
with open('prediction.txt', 'w') as writefile:
    for line in prediction_text:
        writefile.write(line)

# %%
df1 = pd.DataFrame(predicted_class_1, columns = [0,1])
df2 = pd.DataFrame(predicted_class_2, columns = [0,1])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     905     try:
# --> 906         columns = _validate_or_indexify_columns(contents, columns)
#     907     except AssertionError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     953             # caller's responsibility to check for this...
# --> 954             raise AssertionError(
#     955                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 2 columns passed, passed data had 5 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-d649f40ccdf5> in <module>
#       1 df1 = pd.DataFrame(predicted_class_1, columns = [0,1])
# ----> 2 df2 = pd.DataFrame(predicted_class_2, columns = [0,1])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     692                         # ndarray], Index, Series], Sequence[Any]]"
#     693                         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 694                     arrays, columns, index = nested_data_to_arrays(
#     695                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     696                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     481         columns = ensure_index(data[0]._fields)
#     482
# --> 483     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     484     columns = ensure_index(columns)
#     485
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in to_arrays(data, columns, dtype)
#     805         arr = _list_to_arrays(data)
#     806
# --> 807     content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     808     return content, columns
#     809
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     907     except AssertionError as err:
#     908         # GH#26429 do not raise user-facing AssertionError
# --> 909         raise ValueError(err) from err
#     910
#     911     if len(contents) and contents[0].dtype == np.object_:
#
# ValueError: 2 columns passed, passed data had 5 columns

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,2,2])
ax.scatter(class_1[0], class_1[1], color='dodgerblue', label="Class 1")
ax.scatter(df1[0], df1[1], color='navy', label="Predicted Class 1")
ax.scatter(class_2[0], class_2[1] , color='y', label="Class 2")
ax.scatter(df2[0], df2[1] , color='g', label="Predicted Class 2")
ax.set_xlabel('First Column')
ax.set_ylabel('Second Column')
ax.set_title('Scatter Plot')
plt.legend(loc="upper right")
plt.show()
